# %% [markdown]
# # Pandas biblioteka

# %% [markdown]
# ![image.png](attachment:cb520e5f-168a-4e27-ab5f-7d24eca8ca4b.png)

# %% [markdown]
# Tema ovog casa:
#
# > 1. Trikovi u pandas biblioteci <br>
# > 2. Filtriranje na pandas nacin <br>
# > 3. spajanje pandas DataFrame <br>

# %% [markdown]
# ## 1. Lociranje i editovanje podataka

# %% [markdown]
# U proteklih nekoliko predavanja naučili smo o nekoliko različitih načina filtriranja podataka, od maskiranja u Numpy nizovima, do filtera() u prošlom predavanju. Danas ćemo naučiti o filtriranju pandas DataFrame podataka da bismo postigli neke od istih zadataka, ali sa više fleksibilnosti i lakoće.
